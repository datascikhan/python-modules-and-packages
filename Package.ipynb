# %% [raw]
# # Jupyter notebook mein package create karne kalie
# - Step 1: Notebok mein ek cell mein likho
#    - !mkdir mypackage  # yeh ek folder create karega mypackage name ka
#
# - Step 02: ___init__.py file create karo.
#   - Yeh file python ko batati hai ke mypackage ek package hai
#     - %% writefile mypackage/__init__.py
#
#
# - Step 03: Package ke andar module create karo
#     - Ab mypackage folder ke andar ek file banao, jaise basic_math.py:
#     - %%writefile mypackage/basic_math.py
#     - def add(a,b):
#        return a + b
#     - def sub(a,b):
#        return a -b
#     - def multiply(a,b):
#         return a * b
#     - def division(a,b):
#         return a / b
#
# - Step 04 : ek aur new file crete karo
#    - %%writefile mypackage/string.py
#    - def capitalize_words(text):
#          return text.title()
#    - def reverse_string(text):
#          return text[::-1]
#
# - Step 05: Ab Package import karo.
#     - from mypackage import basic_math, string
#     - print(basic_math.add(10, 50))
#     - print(string.reverse_string("sher khan"))

# %%
# Step 01: Ek package folder create karo jupyter mein
# !mkdir mypackage
# Out:
# mkdir: cannot create directory ‘mypackage’: File exists

# %%
# %%writefile mypackage/__init__.py
# Note: yeh line cell ke start mein hone chaye - isse pehle koi aur code, comment, ya blank space nhi hone chaye, Ager
# kuch likha huwa hoga toh jupyter isse "magic comman" nhi samjhe ga
# Step 02: __init__.py file create karo
# yeh file python ko batati hai ke mypackage ek package hai
# Out:
# Overwriting mypackage/__init__.py

# %%
# %%writefile mypackage/basic_math.py

# Step 3: Ab mypackage ke andar ek file create karo, jaise basic_math.py

def add(a,b):
    return a + b

def sub(a,b):
    return a -b

def multiply(a,b):
    return a * b

def division(a,b):
    return a / b
# Out:
# Overwriting mypackage/basic_math.py

# %%
# ek dusre file create karo

# %%
# %%writefile mypackage/string.py
def capitalize_words(text):
    return text.title()

def reverse_string(text):
    return text[::-1]
# Out:
# Overwriting mypackage/string.py
